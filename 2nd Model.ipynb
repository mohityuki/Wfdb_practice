# %%
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
import shutil
import wfdb
import pandas as pd
import cardio as car

# %%
dir(wfdb)
# Out:
# ['Annotation',
#  'MultiRecord',
#  'Record',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'dl_database',
#  'dl_files',
#  'get_dbs',
#  'get_record_list',
#  'io',
#  'plot',
#  'plot_all_records',
#  'plot_items',
#  'plot_wfdb',
#  'rdann',
#  'rdheader',
#  'rdrecord',
#  'rdsamp',
#  'set_db_index_url',
#  'show_ann_classes',
#  'show_ann_labels',
#  'version',
#  'wrann',
#  'wrsamp']

# %%
help(wfdb.Annotation)
# Out:
# Help on class Annotation in module wfdb.io.annotation:
#
# class Annotation(builtins.object)
#  |  The class representing WFDB annotations.
#  |
#  |  Annotation objects can be created using the initializer, or by reading a
#  |  WFDB annotation file with `rdann`.
#  |
#  |  The attributes of the Annotation object give information about the
#  |  annotation as specified by:
#  |  https://www.physionet.org/physiotools/wag/annot-5.htm
#  |
#  |  Call `show_ann_labels()` to see the list of standard annotation codes. Any
#  |  text used to label annotations that are not one of these codes should go in
#  |  the 'aux_note' field rather than the 'sym' field.
#  |
#  |  Examples
#  |  --------
#  |  >>> ann1 = wfdb.Annotation(record_name='rec1', extension='atr',
#  |                             sample=[10,20,400], symbol=['N','N','['],
#  |                             aux_note=[None, None, 'Serious Vfib'])
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, other)
# ...

# %%
record=wfdb.rdrecord("C:/Users/mohit/Downloads/PHM/MODEL_2/wrist PPG dataset/s1_high_resistance_bike")

# %%
display(record.__dict__)

# %%
anno=wfdb.rdann("C:/Users/mohit/Downloads/PHM/MODEL_2/wrist PPG dataset/s1_high_resistance_bike",'atr')
type(anno)
# Out:
# wfdb.io.annotation.Annotation

# %%
wfdb.plot_wfdb(record=record,annotation=anno,title='Feature Vs Time',figsize=(10,70),time_units='minutes',plot_sym=True)

# %%
anno

# %%
tm,signal=wfdb.rdsamp("C:/Users/mohit/Downloads/PHM/MODEL_2/wrist PPG dataset/s1_high_resistance_bike")

# %%
signal.keys()
# Out:
# dict_keys(['fs', 'sig_len', 'n_sig', 'base_date', 'base_time', 'units', 'sig_name', 'comments'])

# %%
type(tm)
# Out:
# numpy.ndarray

# %%
tm.shape
# Out:
# (150785, 15)

# %%
signal["sig_len"]
# Out:
# 150785

# %%
import missingno as msno

# %%
type(record)
# Out:
# wfdb.io.record.Record

# %%
#wfdb.show_ann_labels()

# %%
dir(car)
# Out:
# ['EcgBatch',
#  'EcgDataset',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'add_actions',
#  'core',
#  'dataset',
#  'ecg_batch',
#  'ecg_batch_tools',
#  'ecg_dataset',
#  'kernels',
#  'utils']

# %%
help(car.dataset)
# Out:
# Help on package cardio.dataset.dataset in cardio.dataset:
#
# NAME
#     cardio.dataset.dataset - Dataset enables a fast processing of large dataset using flexible pipelines
#
# PACKAGE CONTENTS
#     base
#     batch
#     batch_base
#     batch_image
#     components
#     config
#     dataset
#     decorators
#     dsindex
#     exceptions
#     jointdataset
#     model_dir
#     models (package)
#     named_expr
#     opensets (package)
#     pipeline
#     utils
#     variables
#
# DATA
#     CROP_00 = -2
#     CROP_CENTER = -1
#
# VERSION
#     0.3.0
#
# FILE
#     c:\users\mohit\anaconda3\lib\site-packages\cardio\dataset\dataset\__init__.py

# %%
help(car.dataset.models)
# Out:
# Help on package cardio.dataset.dataset.models in cardio.dataset.dataset:
#
# NAME
#     cardio.dataset.dataset.models - Contains models
#
# PACKAGE CONTENTS
#     base
#     keras (package)
#     sklearn
#     tf (package)
#
# FILE
#     c:\users\mohit\anaconda3\lib\site-packages\cardio\dataset\dataset\models\__init__.py

# %%
import cardio.dataset as ds
index = ds.FilesIndex(path="ecg/tests/data/*.hea", no_ext=True, sort=True)

# %%
print(index.indices)
# Out:
# []

# %%
import cardio
help(cardio.tests.data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-c3d84eca0d18> in <module>()
#       1 import cardio
# ----> 2 help(cardio.tests.data)
#
# AttributeError: module 'cardio' has no attribute 'tests'
